# %%
#I want to play with functions:

import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
print('we are on!')
# Out:
# we are on!

# %%
data = pd.read_excel('Maven Supplies Raw.xlsx', skiprows=3, index_col= False)
data.head()
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Row ID        Order ID Order Date (MDY) Ship Date (MDY) Order Date (DMY)  \
# 0       1  CA-2017-152156       2017-11-08      2017-11-11        8/11/2017
# 1       2  CA-2017-152156       2017-11-08      2017-11-11        8/11/2017
# 2       3  CA-2017-138688       2017-06-12      2017-06-16        12/6/2017
# 3       4  US-2016-108966       2016-10-11      2016-10-18       11/10/2016
# 4       5  US-2016-108966       2016-10-11      2016-10-18       11/10/2016
#
#   Ship Date (DMY)       Ship Mode Customer ID    Customer Name    Segment  \
# 0      11/11/2017    Second Class    CG-12520      Claire Gute   Consumer
# 1      11/11/2017    Second Class    CG-12520      Claire Gute   Consumer
# ...

# %%
# Get more info about data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date (MDY)   9994 non-null   datetime64[ns]
#  3   Ship Date (MDY)    9994 non-null   datetime64[ns]
#  4   Order Date (DMY)   9994 non-null   object
#  5   Ship Date (DMY)    9994 non-null   object
#  6   Ship Mode          9994 non-null   object
#  7   Customer ID        9994 non-null   object
#  8   Customer Name      9994 non-null   object
#  9   Segment            9994 non-null   object
#  10  Country            9994 non-null   object
#  11  City               9994 non-null   object
#  12  State              9994 non-null   object
#  13  Postal Code        9983 non-null   float64
#  14  Region             9994 non-null   object
# ...

# %%
# Let's have a look at the column

data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date (MDY)', 'Ship Date (MDY)',
#        'Order Date (DMY)', 'Ship Date (DMY)', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Number of Records'],
#       dtype='object')

# %%
data.shape
# Out:
# (9994, 24)

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit  Number of Records
# count  9994.000000             9994.0
# mean     28.656896                1.0
# std     234.260108                0.0
# min   -6599.978000                1.0
# 25%       1.728750                1.0
# 50%       8.666500                1.0
# 75%      29.364000                1.0
# ...

# %%
import datetime

# %%
# Add a new month column to the dataset
data['month']= pd.DatetimeIndex(data['Order Date (MDY)']).month
data.head()
# Out:
#    Row ID        Order ID Order Date (MDY) Ship Date (MDY) Order Date (DMY)  \
# 0       1  CA-2017-152156       2017-11-08      2017-11-11        8/11/2017
# 1       2  CA-2017-152156       2017-11-08      2017-11-11        8/11/2017
# 2       3  CA-2017-138688       2017-06-12      2017-06-16        12/6/2017
# 3       4  US-2016-108966       2016-10-11      2016-10-18       11/10/2016
# 4       5  US-2016-108966       2016-10-11      2016-10-18       11/10/2016
#
#   Ship Date (DMY)       Ship Mode Customer ID    Customer Name    Segment  \
# 0      11/11/2017    Second Class    CG-12520      Claire Gute   Consumer
# 1      11/11/2017    Second Class    CG-12520      Claire Gute   Consumer
# 2       16/6/2017    Second Class    DV-13045  Darrin Van Huff  Corporate
# 3      18/10/2016  Standard Class    SO-20335   Sean O'Donnell   Consumer
# 4      18/10/2016  Standard Class    SO-20335   Sean O'Donnell   Consumer
#
#    ...       Product ID         Category Sub-Category  \
# ...

# %%
data.columns.values
# Out:
# array(['Row ID', 'Order ID', 'Order Date (MDY)', 'Ship Date (MDY)',
#        'Order Date (DMY)', 'Ship Date (DMY)', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Number of Records', 'month'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date (MDY)   9994 non-null   datetime64[ns]
#  3   Ship Date (MDY)    9994 non-null   datetime64[ns]
#  4   Order Date (DMY)   9994 non-null   object
#  5   Ship Date (DMY)    9994 non-null   object
#  6   Ship Mode          9994 non-null   object
#  7   Customer ID        9994 non-null   object
#  8   Customer Name      9994 non-null   object
#  9   Segment            9994 non-null   object
#  10  Country            9994 non-null   object
#  11  City               9994 non-null   object
#  12  State              9994 non-null   object
#  13  Postal Code        9983 non-null   float64
#  14  Region             9994 non-null   object
# ...
